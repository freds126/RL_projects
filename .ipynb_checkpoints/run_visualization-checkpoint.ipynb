# %%
run maze.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/skola/rl/maze.py:380
#     377 horizon =   T     # TODO: Finite horizon
#     379 # Solve the MDP problem with dynamic programming
# --> 380 V, policy = dynamic_programming(env, horizon)
#     382 # Simulate the shortest path starting from position A
#     383 method = 'DynProg'
#
# File ~/skola/rl/maze.py:295, in dynamic_programming(env, horizon)
#     284 #TODO
#     287 """
#     288 S = 10000
#     289 V = np.random.random_integers(0, 10, (S, T))
#    (...)
#     293 policy = policy*4
#     294 """
# --> 295 return V, policy
#
# NameError: name 'V' is not defined

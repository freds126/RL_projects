# %%
run maze.py
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/skola/rl/maze.py:934
#     932     path = env.simulate(start, policy, method)[0]
#     933     NUM_WINS += ('Win' in path)
# --> 934     animate_solution(maze, path)
#     935 """
#     936 plt.figure(1)
#     937 plt.title("Rewards")
#    (...)
#     942 plt.show()
#     943 """
#     946 print(f"Probability of winning: {NUM_WINS / NUM_SIMULATIONS}")
#
# File ~/skola/rl/maze.py:872, in animate_solution(maze, path)
#     869     cells[(mr, mc)].set_facecolor(col_map[-1])  # minotaur
#     871 # Re-display the SAME figure
# --> 872 display.display(fig)
#     873 time.sleep(0.1)
#
# File /usr/lib/python3/dist-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
# ...

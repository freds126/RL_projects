# %%
run maze.py
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/skola/rl/maze.py:821
#     819     path = env.simulate(start, policy, method)[0]
#     820     NUM_WINS += (path[-1] == 'Win')
# --> 821     animate_solution(maze, path)
#     822 #plt.figure(1)
#     823 #plt.title("Rewards")
#     824 #plt.plot(rewards)
#    (...)
#     827 #plt.plot(V_starts)
#     828 #plt.show()
#     832 print(f"Probability of winning: {NUM_WINS / NUM_SIMULATIONS}")
#
# File ~/skola/rl/maze.py:760, in animate_solution(maze, path)
#     758     grid.get_celld()[(path[i][0])].set_facecolor(col_map[-2]) # Position of the player
#     759     grid.get_celld()[(path[i][1])].set_facecolor(col_map[-1]) # Position of the minotaur
# --> 760 display.display(fig)
#     761 time.sleep(0.1)
#     762 display.clear_output(wait = True)
#
# ...

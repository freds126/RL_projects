# %%
run maze.py
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\skola\rl\RL_projects\maze.py:1162
#    1160     path = env.simulate(start, policy, method)[0]
#    1161     NUM_WINS += ('Win' in path)
# -> 1162     animate_solution(maze, path, save_figs=False)
#    1164 plot_reward = False
#    1165 if plot_reward:
#
# File ~\skola\rl\RL_projects\maze.py:798, in animate_solution(maze, path, save_figs)
#     795     cells[(mr, mc)].set_facecolor(col_map[-1])  # minotaur
#     797 # Re-display the SAME figure
# --> 798 display.display(fig)
#     800 if save_figs:
#     801     # Save each frame (overwrite numbering each run)
#     802     fig.savefig(f"{save_dir}/frame_{frame_id:03d}.png", dpi=120, bbox_inches="tight")
#
# ...
